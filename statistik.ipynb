# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.close("all")

# %%
investDATA = pd.read_excel("./Invest værdipapirer.xlsx","Complete")

# %%
In [134]: ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

In [135]: ts = ts.cumsum()

In [136]: ts.plot();

# %%
investDATA
# Out:
#     Hvad er din alder?  \
# 0              20 - 21
# 1              22 - 23
# 2        24 eller mere
# 3                  NaN
# 4              22 - 23
# ..                 ...
# 179            20 - 21
# 180            20 - 21
# 181            22 - 23
# 182            20 - 21
# 183      24 eller mere
#
#     Angiv din adgangsgivende eksamen til din nuværende uddannelse  \
# 0                         STX (Almen studentereksamen)
# 1                                                  HHX
# 2                         STX (Almen studentereksamen)
# 3                                                  NaN
# 4                                                  HHX
# ..                                                 ...
# 179                       STX (Almen studentereksamen)
# 180                                                HHX
# 181                                                HHX
# 182                                                HTX
# ...

# %%
alderOgUddannelse = pd.DataFrame(investDATA["Hvad er din alder?"],investDATA["Angiv din adgangsgivende eksamen til din nuværende uddannelse"], columns=['A','B'])

# %%
alder
# Out:
# 0            20 - 21
# 1            22 - 23
# 2      24 eller mere
# 3                NaN
# 4            22 - 23
#            ...
# 179          20 - 21
# 180          20 - 21
# 181          22 - 23
# 182          20 - 21
# 183    24 eller mere
# Name: Hvad er din alder?, Length: 184, dtype: object
